# %% [markdown]
# <a href="https://colab.research.google.com/github/sehbanf/AI_Assignments/blob/main/creatingCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/Original_Text.txt",sep = '\t')

# %%
df1.isnull().sum()
# Out:
# Original Text    0
# dtype: int64

# %%
df1.describe()
# Out:
#                                             Original Text
# count                                                  46
# unique                                                 45
# top     Ordering Playseats products Online is designed...
# freq                                                    2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Original Text  46 non-null     object
# dtypes: object(1)
# memory usage: 496.0+ bytes

# %%
df1.head()
# Out:
#                                        Original Text
# 0  Policy & Legal Notice: R.S. Hughes Company, In...
# 1  If you require any more information or have an...
# 2  This Privacy Notice (the “Notice”) was develop...
# 3  We collect basic information such as, but not ...
# 4  MyFolio.com's Privacy Policy hereby states the...

# %%
df2 = pd.read_csv("/content/Summary",sep = '\t')

# %%
df2.isnull().sum()
# Out:
# Summary    0
# dtype: int64

# %%
df2.describe()
# Out:
#                                                   Summary
# count                                                  46
# unique                                                 46
# top     R.S. Hughes Company, Inc. is committed to prot...
# freq                                                    1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Summary  46 non-null     object
# dtypes: object(1)
# memory usage: 496.0+ bytes

# %%
df2.head()
# Out:
#                                              Summary
# 0  R.S. Hughes Company, Inc. is committed to prot...
# 1  308AR.com, like many other websites, makes use...
# 2  Healthy Lifestyle Brands, LLC produced this Pr...
# 3  We collect basic information such as IP addres...
# 4  Users' personal information is collected by My...

# %%
df3 = pd.read_csv("/content/Policy_Names",sep = '\t')

# %%
df3.isnull().sum()
# Out:
# Policy Name    0
# dtype: int64

# %%
df3.describe()
# Out:
#        Policy Name
# count           46
# unique          44
# top       Playseat
# freq             2

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Policy Name  46 non-null     object
# dtypes: object(1)
# memory usage: 496.0+ bytes

# %%
df3.head()
# Out:
#                    Policy Name
# 0          R.S. Hughes Company
# 1                    308AR.com
# 2                   drweil.com
# 3  cardgamespidersolitaire.com
# 4                  myfolio.com

# %%
result = pd.concat([df3,df1, df2], axis=1, join='outer')

# %%
result.head()
# Out:
#                    Policy Name  \
# 0          R.S. Hughes Company
# 1                    308AR.com
# 2                   drweil.com
# 3  cardgamespidersolitaire.com
# 4                  myfolio.com
#
#                                        Original Text  \
# 0  Policy & Legal Notice: R.S. Hughes Company, In...
# 1  If you require any more information or have an...
# 2  This Privacy Notice (the “Notice”) was develop...
# 3  We collect basic information such as, but not ...
# 4  MyFolio.com's Privacy Policy hereby states the...
#
#                                              Summary
# 0  R.S. Hughes Company, Inc. is committed to prot...
# 1  308AR.com, like many other websites, makes use...
# 2  Healthy Lifestyle Brands, LLC produced this Pr...
# 3  We collect basic information such as IP addres...
# 4  Users' personal information is collected by My...

# %%
result.to_csv('dataset.csv',index=None)

# %%
n = pd.read_csv("/content/dataset.csv")

# %%
n
# Out:
#                         Policy Name  \
# 0               R.S. Hughes Company
# 1                         308AR.com
# 2                        drweil.com
# 3       cardgamespidersolitaire.com
# 4                       myfolio.com
# 5                    mylivechat.com
# 6                        radmin.com
# 7                            usenix
# 8                      visitage.com
# 9                       evworld.com
# 10                     glamsham.com
# 11                     gulfbase.com
# 12                Hawaiian Airlines
# 13                      Secureworks
# 14                          iWebcam
# 15                         claz.org
# 16                      evworld.com
# 17                         Playseat
# 18             Rentokil Initial plc
# 19                       Supersonic
# 20                     JD.com, Inc.
# 21                      30DayChange
# 22                    300mbmovie.in
# 23                          rSpark
# 24           Hot Business Directory
# ...

# %%
y = n['Policy Name'][45]

# %%
y
# Out:
# 'Knix'
